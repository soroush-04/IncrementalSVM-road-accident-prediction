# %% [markdown]
# <a href="https://colab.research.google.com/github/soroush-04/Road-Accident-prediction/blob/main/SVM_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/MyDrive/Data analytics/Final Project/Copy project/Train_data_Acc.csv',
                   parse_dates=['differ_HHMM','S_time'])

# %%
data_copy = data.copy()

# %%
print('Total Number of {} rows and {} columns in the Accident dataset'.format(data.shape[0],data.shape[1]))
# Out:
# Total Number of 192 rows and 13 columns in the Accident dataset

# %%
print("Null values in the dataset?: {}".format(data.isnull().values.any()))
# Out:
# Null values in the dataset?: False

# %%
print(data.dtypes)
# Out:
# ID_Start_Lat_Lonh                int64
# Severity                         int64
# differ_HHMM             datetime64[ns]
# S_time                  datetime64[ns]
# Month                            int64
# Start_Lat                      float64
# Start_Lng                      float64
# Distance.mi.                   float64
# Accident.Description            object
# Traffic.Speed                    int64
# Street                          object
# City                            object
# Weather_Condition               object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data['Accident.Description']=le.fit_transform(data['Accident.Description'])
data['Accident.Description']
# Out:
# 0      3
# 1      3
# 2      7
# 3      3
# 4      3
#       ..
# 187    3
# 188    0
# 189    1
# 190    3
# 191    1
# Name: Accident.Description, Length: 192, dtype: int64

# %%
data['Street']=le.fit_transform(data['Street'])
data['Street']
# Out:
# 0      10
# 1      10
# 2       5
# 3      13
# 4      14
#        ..
# 187    13
# 188     8
# 189     9
# 190    13
# 191     6
# Name: Street, Length: 192, dtype: int64

# %%
data['City']=le.fit_transform(data['City'])

# %%
data['Weather_Condition']=le.fit_transform(data['Weather_Condition'])

# %%
print(data.dtypes)
# Out:
# ID_Start_Lat_Lonh                int64
# Severity                         int64
# differ_HHMM             datetime64[ns]
# S_time                  datetime64[ns]
# Month                            int64
# Start_Lat                      float64
# Start_Lng                      float64
# Distance.mi.                   float64
# Accident.Description             int64
# Traffic.Speed                    int64
# Street                           int64
# City                             int64
# Weather_Condition                int64
# dtype: object

# %%
X = data.drop(columns=['Severity'])
y = data['Severity']

# %%
print(X.head(5))
# Out:
#    ID_Start_Lat_Lonh         differ_HHMM              S_time  Month  \
# 0                  1 2023-07-20 00:45:00 2017-12-30 09:01:00     12
# 1                  1 2023-07-20 00:59:00 2017-12-27 13:18:00     12
# 2                  6 2023-07-20 00:29:00 2017-12-22 17:52:00     12
# 3                  8 2023-07-20 00:30:00 2017-12-19 20:22:00     12
# 4                  9 2023-07-20 00:27:00 2017-12-15 22:33:00     12
#
#    Start_Lat  Start_Lng  Distance.mi.  Accident.Description  Traffic.Speed  \
# 0   41.10979  -73.80144           0.0                     3             28
# 1   41.10979  -73.80144           0.0                     3             25
# 2   40.77143  -73.87611           0.0                     7             20
# 3   41.67018  -73.78852           0.0                     3             39
# 4   41.40964  -73.78676           0.0                     3             39
#
#    Street  City  Weather_Condition
# 0      10     6                  5
# 1      10     6                  8
# 2       5     4                  7
# 3      13     8                 10
# 4      14    12                  6

# %%
X['differ_HHMM']=le.fit_transform(X['differ_HHMM'])
X['S_time']=le.fit_transform(X['S_time'])

# %%
print(X.dtypes)
# Out:
# ID_Start_Lat_Lonh         int64
# differ_HHMM               int64
# S_time                    int64
# Month                     int64
# Start_Lat               float64
# Start_Lng               float64
# Distance.mi.            float64
# Accident.Description      int64
# Traffic.Speed             int64
# Street                    int64
# City                      int64
# Weather_Condition         int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30,random_state=1)

# %%
X_test_copy=X_test.copy()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
from sklearn import svm

clf = svm.SVC()

clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict(X_test)

from sklearn import metrics

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9482758620689655

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[28  2]
#  [ 1 27]]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Assuming you have your classifier 'clf', test data 'X_test', and corresponding true labels 'y_test'

# Get the predicted labels from your classifier
y_pred = clf.predict(X_test)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Create the ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# Plot the confusion matrix
disp.plot()

# Show the plot
plt.show()

# %%
df = pd.DataFrame(X_test_copy)

# %%
print(df)
# Out:
#      ID_Start_Lat_Lonh  differ_HHMM  S_time  Month  Start_Lat  Start_Lng  \
# 44                  16            4     147     10   40.74010  -73.84543
# 69                  35            8     122      8   41.77643  -73.76835
# 161                 26            4      30      2   40.69165  -73.99931
# 35                  40            8     156     10   40.82445  -73.87260
# 182                 26            4       9      1   40.69165  -73.99931
# 11                  19            7     180     11   40.82236  -73.88721
# 122                 66            4      69      4   40.70174  -73.99126
# 81                  26            4     110      7   40.69165  -73.99931
# 110                 20            4      81      5   41.05513  -73.81042
# 180                 12            4      11      1   40.73431  -73.92232
# 172                  9            5      19      2   41.40964  -73.78676
# 127                 40            8      64      4   40.82445  -73.87260
# 29                  12            4     162     10   40.73431  -73.92232
# 16                  26            4     175     11   40.69165  -73.99931
# 108                 20            4      83      5   41.05513  -73.81042
# 67                  32            8     124      8   41.25376  -73.80881
# 28                  37            4     163     10   40.92158  -73.80969
# 51                  32            7     140      9   41.25376  -73.80881
# 31                  18            8     159     10   41.53931  -73.77114
# 155                 18            7      36      2   41.53931  -73.77114
# 47                  35            7     144      9   41.77643  -73.76835
# 4                    9            1     186     12   41.40964  -73.78676
# 97                  18            8      94      6   41.53931  -73.77114
# 187                 35            7       4      1   41.77643  -73.76835
# 56                  35            2     135      9   41.77643  -73.76835
# 106                 26            3      85      5   40.69165  -73.99931
# 152                 66            3      39      3   40.70174  -73.99126
# 82                  40            8     109      7   40.82445  -73.87260
# 53                  35            8     138      9   41.77643  -73.76835
# 130                 12            8      61      4   40.73431  -73.92232
# 66                  12            3     125      8   40.73431  -73.92232
# 119                 14            7      72      4   40.66711  -73.99592
# 58                  12            7     133      8   40.73431  -73.92232
# 84                   1            3     107      7   41.10979  -73.80144
# 186                 14            4       5      1   40.66711  -73.99592
# 14                  12            8     177     11   40.73431  -73.92232
# 40                  34            8     151     10   40.84514  -73.92654
# 19                  18            8     172     11   41.53931  -73.77114
# 164                 18            8      27      2   41.53931  -73.77114
# 190                 35            7       2      1   41.77643  -73.76835
# 113                 37            4      78      5   40.92158  -73.80969
# 174                 34            8      17      2   40.84514  -73.92654
# 167                 51            8      24      2   41.02558  -73.73134
# 150                  1            4      41      3   41.10979  -73.80144
# 33                  12            3     158     10   40.73431  -73.92232
# 170                  9            3      21      2   41.40964  -73.78676
# 160                 14            8      31      2   40.66711  -73.99592
# 59                  34            8     132      8   40.84514  -73.92654
# 165                  6            8      26      2   40.77143  -73.87611
# 112                 20            8      79      5   41.05513  -73.81042
# 42                  35            8     149     10   41.77643  -73.76835
# 17                  27            8     174     11   40.83742  -73.88061
# 5                   12            3     185     12   40.73431  -73.92232
# 116                  9            2      75      5   41.40964  -73.78676
# 48                  37            4     143      9   40.92158  -73.80969
# 39                  15            4     152     10   41.18482  -73.80740
# 73                   1            4     118      7   41.10979  -73.80144
# 78                  15            8     113      7   41.18482  -73.80740
#
#      Distance.mi.  Accident.Description  Traffic.Speed  Street  City  \
# 44           0.00                     7             22       6     3
# 69           0.00                     3             27      13    11
# 161          0.01                     4             33       1     1
# 35           0.00                     4             20       0     0
# 182          0.01                     4             32       1     1
# 11           0.00                     4             28      11     0
# 122          0.97                     7             24       1     1
# 81           0.00                     4             33       1     1
# 110          0.01                     3             24      12     5
# 180          0.01                     4             28       8     9
# 172          0.01                     3             24      14    12
# 127          0.01                     1             22       0     0
# 29           0.00                     7             22       8     9
# 16           0.00                     4             32       1     1
# 108          0.01                     3             24      12     5
# 67           0.00                     3             27      15    14
# 28           0.00                     3             24       7    10
# 51           0.00                     3             24      15    14
# 31           0.00                     3             19      13     7
# 155          0.01                     3             23      13     7
# 47           0.00                     3             37      13    11
# 4            0.00                     3             39      14    12
# 97           0.00                     4             26      13     7
# 187          0.01                     3             39      13    11
# 56           0.00                     3             43      13    11
# 106          0.01                     4             32       1     1
# 152          0.01                     1             20       1     1
# 82           0.00                     1             22       0     0
# 53           0.00                     3             20      13    11
# 130          0.01                     7             19       8     9
# 66           0.00                     7             20       8     9
# 119          0.01                     4             20       4     1
# 58           0.00                     2             22       8     9
# 84           0.00                     3             37      10     6
# 186          0.01                     4             38       4     1
# 14           0.00                     4             15       8     9
# 40           0.00                     4             15       9     0
# 19           0.00                     3             21      13     7
# 164          0.01                     3             23      13     7
# 190          0.01                     3             32      13    11
# 113          0.01                     3             24       7    10
# 174          0.01                     1             28       9     0
# 167          0.01                     3             19       3    13
# 150          0.01                     3             37      10     6
# 33           0.00                     4             28       8     9
# 170          0.01                     3             37      14    12
# 160          0.01                     4             28       4     1
# 59           0.00                     7             13       9     0
# 165          0.01                     1             21       5     4
# 112          0.01                     3             24      12     5
# 42           0.00                     3             27      13    11
# 17           0.00                     4             22       2     0
# 5            0.00                     7             20       8     9
# 116          0.01                     3             29      14    12
# 48           0.00                     3             21       7    10
# 39           0.00                     3             46      15     2
# 73           0.00                     3             28      10     6
# 78           0.00                     3             26      15     2
#
#      Weather_Condition
# 44                   6
# 69                   4
# 161                  0
# 35                   8
# 182                  7
# 11                   8
# 122                  7
# 81                   7
# 110                  6
# 180                  6
# 172                  1
# 127                 10
# 29                   4
# 16                   7
# 108                 10
# 67                   8
# 28                   7
# 51                  10
# 31                   0
# 155                  0
# 47                   7
# 4                    6
# 97                   0
# 187                  6
# 56                   0
# 106                  7
# 152                  0
# 82                  10
# 53                   6
# 130                 10
# 66                   8
# 119                  0
# 58                   4
# 84                   2
# 186                  7
# 14                   6
# 40                   7
# 19                   0
# 164                  0
# 190                  7
# 113                 10
# 174                  8
# 167                  5
# 150                  0
# 33                   8
# 170                  6
# 160                  0
# 59                   6
# 165                  6
# 112                  0
# 42                   8
# 17                   9
# 5                    6
# 116                  3
# 48                   6
# 39                   0
# 73                  10
# 78                   8

# %%
df['y_test']=y_test

# %%
df['y_pred']=y_pred

# %%
print(df)
# Out:
#      ID_Start_Lat_Lonh  differ_HHMM  S_time  Month  Start_Lat  Start_Lng  \
# 44                  16            4     147     10   40.74010  -73.84543
# 69                  35            8     122      8   41.77643  -73.76835
# 161                 26            4      30      2   40.69165  -73.99931
# 35                  40            8     156     10   40.82445  -73.87260
# 182                 26            4       9      1   40.69165  -73.99931
# 11                  19            7     180     11   40.82236  -73.88721
# 122                 66            4      69      4   40.70174  -73.99126
# 81                  26            4     110      7   40.69165  -73.99931
# 110                 20            4      81      5   41.05513  -73.81042
# 180                 12            4      11      1   40.73431  -73.92232
# 172                  9            5      19      2   41.40964  -73.78676
# 127                 40            8      64      4   40.82445  -73.87260
# 29                  12            4     162     10   40.73431  -73.92232
# 16                  26            4     175     11   40.69165  -73.99931
# 108                 20            4      83      5   41.05513  -73.81042
# 67                  32            8     124      8   41.25376  -73.80881
# 28                  37            4     163     10   40.92158  -73.80969
# 51                  32            7     140      9   41.25376  -73.80881
# 31                  18            8     159     10   41.53931  -73.77114
# 155                 18            7      36      2   41.53931  -73.77114
# 47                  35            7     144      9   41.77643  -73.76835
# 4                    9            1     186     12   41.40964  -73.78676
# 97                  18            8      94      6   41.53931  -73.77114
# 187                 35            7       4      1   41.77643  -73.76835
# 56                  35            2     135      9   41.77643  -73.76835
# 106                 26            3      85      5   40.69165  -73.99931
# 152                 66            3      39      3   40.70174  -73.99126
# 82                  40            8     109      7   40.82445  -73.87260
# 53                  35            8     138      9   41.77643  -73.76835
# 130                 12            8      61      4   40.73431  -73.92232
# 66                  12            3     125      8   40.73431  -73.92232
# 119                 14            7      72      4   40.66711  -73.99592
# 58                  12            7     133      8   40.73431  -73.92232
# 84                   1            3     107      7   41.10979  -73.80144
# 186                 14            4       5      1   40.66711  -73.99592
# 14                  12            8     177     11   40.73431  -73.92232
# 40                  34            8     151     10   40.84514  -73.92654
# 19                  18            8     172     11   41.53931  -73.77114
# 164                 18            8      27      2   41.53931  -73.77114
# 190                 35            7       2      1   41.77643  -73.76835
# 113                 37            4      78      5   40.92158  -73.80969
# 174                 34            8      17      2   40.84514  -73.92654
# 167                 51            8      24      2   41.02558  -73.73134
# 150                  1            4      41      3   41.10979  -73.80144
# 33                  12            3     158     10   40.73431  -73.92232
# 170                  9            3      21      2   41.40964  -73.78676
# 160                 14            8      31      2   40.66711  -73.99592
# 59                  34            8     132      8   40.84514  -73.92654
# 165                  6            8      26      2   40.77143  -73.87611
# 112                 20            8      79      5   41.05513  -73.81042
# 42                  35            8     149     10   41.77643  -73.76835
# 17                  27            8     174     11   40.83742  -73.88061
# 5                   12            3     185     12   40.73431  -73.92232
# 116                  9            2      75      5   41.40964  -73.78676
# 48                  37            4     143      9   40.92158  -73.80969
# 39                  15            4     152     10   41.18482  -73.80740
# 73                   1            4     118      7   41.10979  -73.80144
# 78                  15            8     113      7   41.18482  -73.80740
#
#      Distance.mi.  Accident.Description  Traffic.Speed  Street  City  \
# 44           0.00                     7             22       6     3
# 69           0.00                     3             27      13    11
# 161          0.01                     4             33       1     1
# 35           0.00                     4             20       0     0
# 182          0.01                     4             32       1     1
# 11           0.00                     4             28      11     0
# 122          0.97                     7             24       1     1
# 81           0.00                     4             33       1     1
# 110          0.01                     3             24      12     5
# 180          0.01                     4             28       8     9
# 172          0.01                     3             24      14    12
# 127          0.01                     1             22       0     0
# 29           0.00                     7             22       8     9
# 16           0.00                     4             32       1     1
# 108          0.01                     3             24      12     5
# 67           0.00                     3             27      15    14
# 28           0.00                     3             24       7    10
# 51           0.00                     3             24      15    14
# 31           0.00                     3             19      13     7
# 155          0.01                     3             23      13     7
# 47           0.00                     3             37      13    11
# 4            0.00                     3             39      14    12
# 97           0.00                     4             26      13     7
# 187          0.01                     3             39      13    11
# 56           0.00                     3             43      13    11
# 106          0.01                     4             32       1     1
# 152          0.01                     1             20       1     1
# 82           0.00                     1             22       0     0
# 53           0.00                     3             20      13    11
# 130          0.01                     7             19       8     9
# 66           0.00                     7             20       8     9
# 119          0.01                     4             20       4     1
# 58           0.00                     2             22       8     9
# 84           0.00                     3             37      10     6
# 186          0.01                     4             38       4     1
# 14           0.00                     4             15       8     9
# 40           0.00                     4             15       9     0
# 19           0.00                     3             21      13     7
# 164          0.01                     3             23      13     7
# 190          0.01                     3             32      13    11
# 113          0.01                     3             24       7    10
# 174          0.01                     1             28       9     0
# 167          0.01                     3             19       3    13
# 150          0.01                     3             37      10     6
# 33           0.00                     4             28       8     9
# 170          0.01                     3             37      14    12
# 160          0.01                     4             28       4     1
# 59           0.00                     7             13       9     0
# 165          0.01                     1             21       5     4
# 112          0.01                     3             24      12     5
# 42           0.00                     3             27      13    11
# 17           0.00                     4             22       2     0
# 5            0.00                     7             20       8     9
# 116          0.01                     3             29      14    12
# 48           0.00                     3             21       7    10
# 39           0.00                     3             46      15     2
# 73           0.00                     3             28      10     6
# 78           0.00                     3             26      15     2
#
#      Weather_Condition  y_test  y_pred
# 44                   6       3       3
# 69                   4       2       2
# 161                  0       3       3
# 35                   8       3       3
# 182                  7       3       3
# 11                   8       3       3
# 122                  7       2       2
# 81                   7       3       3
# 110                  6       2       2
# 180                  6       3       3
# 172                  1       2       2
# 127                 10       3       3
# 29                   4       3       3
# 16                   7       3       3
# 108                 10       2       2
# 67                   8       2       2
# 28                   7       2       2
# 51                  10       2       2
# 31                   0       3       2
# 155                  0       2       2
# 47                   7       2       2
# 4                    6       2       2
# 97                   0       2       2
# 187                  6       2       2
# 56                   0       2       2
# 106                  7       3       3
# 152                  0       3       3
# 82                  10       3       3
# 53                   6       2       2
# 130                 10       3       3
# 66                   8       3       3
# 119                  0       3       3
# 58                   4       3       3
# 84                   2       2       2
# 186                  7       3       3
# 14                   6       3       3
# 40                   7       3       3
# 19                   0       2       2
# 164                  0       2       2
# 190                  7       2       2
# 113                 10       2       2
# 174                  8       3       3
# 167                  5       3       3
# 150                  0       2       2
# 33                   8       3       3
# 170                  6       2       2
# 160                  0       3       3
# 59                   6       3       3
# 165                  6       2       3
# 112                  0       2       2
# 42                   8       2       2
# 17                   9       3       3
# 5                    6       3       3
# 116                  3       2       2
# 48                   6       2       2
# 39                   0       2       3
# 73                  10       2       2
# 78                   8       2       2

# %%
df.to_csv('SeverityPoint.csv', index=False)

# %%
location = "/content/SeverityPoint.csv"

# %%
PP = pd.read_csv(location)

# %%
import folium
map = folium.Map(location=[PP.Start_Lat.mean(), PP.Start_Lng.mean()], zoom_start=14, control_scale=True)

# %%
for index, location_info in PP.iterrows():
    folium.Marker([location_info["Start_Lat"], location_info["Start_Lng"]],tooltip=[location_info["y_pred"],location_info["y_test"]],popup="<stong>prediction,test</stong>").add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d286d5b867ac40528eb33b3a965bf4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d286d5b867ac40528eb33b3a965bf4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d286d5b867ac40528eb33b3a965bf4f = L.map(
#                 &quot;map_0d286d5b867ac40528eb33b3a965bf4f&quot;,
#                 {
#                     center: [41.06637896551724, -73.85934086206896],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0d286d5b867ac40528eb33b3a965bf4f);
#
#
#
#
#
#             var tile_layer_87a1ce284b2e0675bd776a59e86e1d3e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0d286d5b867ac40528eb33b3a965bf4f);
#
#
#             var marker_ab8d846c7a00d9aab4ec4a833e686bc2 = L.marker(
#                 [40.7401, -73.84543],
#                 {}
#             ).addTo(map_0d286d5b867ac40528eb33b3a965bf4f);
#
#
#         var popup_7f2b60c4a462b771799801632b5fb851 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9270e3f4187858fb95a611f7feb90d33 = $(`&lt;div id=&quot;html_9270e3f4187858fb95a611f7feb90d33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;stong&gt;prediction,test&lt;/stong&gt;&lt;/div&gt;`)[0];
#                 popup_7f2b60c4a462b771799801632b5fb851.setContent(html_9270e3f4187858fb95a611f7feb90d33);
#
#
#
#         marker_ab8d846c7a00d9aab4ec4a833e686bc2.bindPopup(popup_7f2b60c4a462b771799801632b5fb851)
#         ;
#
#
#
#
#             marker_ab8d846c7a00d9aab4ec4a833e686bc2.bindTooltip(
#                 `&lt;div&gt;
#                      [3.0, 3.0]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1b4555d1b06835b897388f24fbdf258c = L.marker(
#                 [41.77643, -73.76835],
#                 {}
#             ).addTo(map_0d286d5b867ac40528eb33b3a965bf4f);
#
#
#         var popup_6e9105655ecbd70f7b01df96fd6091b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2c00c90f23819347906190406683b75 = $(`&lt;div id=&quot;html_f2c00c90f23819347906190406683b75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;stong&gt;prediction,test&lt;/stong&gt;&lt;/div&gt;`)[0];
#                 popup_6e9105655ecbd70f7b01df96fd6091b7.setContent(html_f2c00c90f23819347906190406683b75);
#
#
#
#         marker_1b4555d1b06835b897388f24fbdf258c.bindPopup(popup_6e9105655ecbd70f7b01df96fd6091b7)
#         ;
#
#
#
#
#             marker_1b4555d1b06835b897388f24fbdf258c.bindTooltip(
#                 `&lt;div&gt;
#                      [2.0, 2.0]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_72c226b05f4d83016361e47910256f4f = L.marker(
#                 [40.69165, -73.99931],
#                 {}
#             ).addTo(map_0d286d5b867ac40528eb33b3a965bf4f);
#
#
#         var popup_bc544b41d42e70c958446fb31b3e0629 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_489bcec9e02d860b9b3b4a81fc7091c7 = $(`&lt;div id=&quot;html_489bcec9e02d860b9b3b4a81fc7091c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;stong&gt;prediction,test&lt;/stong&gt;&lt;/div&gt;`)[0];
#                 popup_bc544b41d42e70c958446fb31b3e0629.setContent(html_489bcec9e02d860b9b3b4a81fc7091c7);
#
#
#
#         marker_72c226b05f4d83016361e47910256f4f.bindPopup(popup_bc544b41d42e70c958446fb31b3e0629)
#         ;
#
#
#
#
#             marker_72c226b05f4d83016361e47910256f4f.bindTooltip(
#                 `&lt;div&gt;
#                      [3.0, 3.0]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_af08beea410f37f0f560e4e066c9c031 = L.marker(
#                 [40.82445, -73.8726],
#                 {}
#             ).addTo(map_0d286d5b867ac40528eb33b3a965bf4f);
#
#
#         var popup_e208b77ca7648b9e8f23629af08d86d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10eb52a448b86343557a1dee76a960ee = $(`&lt;div id=&quot;html_10eb52a448b86343557a1dee76a960ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;stong&gt;prediction,test&lt;/stong&gt;&lt;/div&gt;`)[0];
#                 popup_e208b77ca7648b9e8f23629af08d86d3.setContent(html_10eb52a448b86343557a1dee76a960ee);
#
#
#
#         marker_af08beea410f37f0f560e4e066c9c031.bindPopup(popup_e208b77ca7648b9e8f23629af08d86d3)
#         ;
#
#
#
#
#             marker_af08b

# %%
New_file = pd.read_csv('/content/drive/MyDrive/Data analytics/Final Project/Copy project/dummy_file.csv',
                       parse_dates=['differ_HHMM','S_time'])

# %%
New_file_copy = New_file.copy()

# %%
New_file['Accident.Description']=le.fit_transform(New_file['Accident.Description'])
New_file['Street']=le.fit_transform(New_file['Street'])
New_file['City']=le.fit_transform(New_file['City'])
New_file['Weather_Condition']=le.fit_transform(New_file['Weather_Condition'])

# %%
New_file['differ_HHMM']=le.fit_transform(New_file['differ_HHMM'])
New_file['S_time']=le.fit_transform(New_file['S_time'])

# %%
New_file = scaler.fit_transform(New_file)

# %%
New_pred = clf.predict(New_file)

New_df = pd.DataFrame(New_file_copy)
New_df['y_pred'] = New_pred

# %%
Temp = pd.read_csv('/content/drive/MyDrive/Data analytics/Final Project/Copy project/accident_data_both_speed_16_17_18_19_20.csv')
New_Sev = Temp['Severity']
New_Sev = New_Sev.iloc[:56]
New_Sev
# Out:
# 0     3
# 1     3
# 2     3
# 3     3
# 4     3
# 5     3
# 6     3
# 7     2
# 8     4
# 9     3
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    3
# 16    2
# 17    3
# 18    4
# 19    4
# 20    4
# 21    1
# 22    1
# 23    2
# 24    3
# 25    2
# 26    3
# 27    3
# 28    3
# 29    3
# 30    3
# 31    3
# 32    3
# 33    3
# 34    3
# 35    3
# 36    3
# 37    3
# 38    3
# 39    3
# 40    3
# 41    3
# 42    3
# 43    2
# 44    3
# 45    3
# 46    3
# 47    3
# 48    3
# 49    3
# 50    3
# 51    3
# 52    3
# 53    3
# 54    2
# 55    2
# Name: Severity, dtype: int64

# %%
print("Accuracy:",metrics.accuracy_score(New_pred,New_Sev))
# Out:
# Accuracy: 0.6964285714285714

# %%
df1 = pd.DataFrame(New_file_copy)

# %%
df1['New_pred']=New_pred

# %%
df1.to_csv('Increment_map.csv', index=False)

# %%
location1= "/content/Increment_map.csv"

# %%
PP1 = pd.read_csv(location1)

# %%
import folium
map1 = folium.Map(location=[PP1.Start_Lat.mean(), PP1.Start_Lng.mean()], zoom_start=14, control_scale=True)

# %%
for index, location_info in PP1.iterrows():
    folium.Marker([location_info["Start_Lat"], location_info["Start_Lng"]],tooltip=[location_info["New_pred"]],popup="<stong>prediction</stong>").add_to(map1)

# %%
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17ea60095d3be2007fc1ec53bbc0f59e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17ea60095d3be2007fc1ec53bbc0f59e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17ea60095d3be2007fc1ec53bbc0f59e = L.map(
#                 &quot;map_17ea60095d3be2007fc1ec53bbc0f59e&quot;,
#                 {
#                     center: [40.66165803571429, -73.95740678571428],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_17ea60095d3be2007fc1ec53bbc0f59e);
#
#
#
#
#
#             var tile_layer_822990c4c640c28565ed5e34938e8973 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_17ea60095d3be2007fc1ec53bbc0f59e);
#
#
#             var marker_6c249a1eadb3e36f3c1894d161cf5117 = L.marker(
#                 [40.61955, -74.02346],
#                 {}
#             ).addTo(map_17ea60095d3be2007fc1ec53bbc0f59e);
#
#
#         var popup_064a887af44548893a12ae247c3f0bf9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d7883d09b05ae32c468a7ebe1cdc9bc = $(`&lt;div id=&quot;html_4d7883d09b05ae32c468a7ebe1cdc9bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;stong&gt;prediction&lt;/stong&gt;&lt;/div&gt;`)[0];
#                 popup_064a887af44548893a12ae247c3f0bf9.setContent(html_4d7883d09b05ae32c468a7ebe1cdc9bc);
#
#
#
#         marker_6c249a1eadb3e36f3c1894d161cf5117.bindPopup(popup_064a887af44548893a12ae247c3f0bf9)
#         ;
#
#
#
#
#             marker_6c249a1eadb3e36f3c1894d161cf5117.bindTooltip(
#                 `&lt;div&gt;
#                      [3]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_92f44c9feb804820fa41ceb9f2dbb871 = L.marker(
#                 [40.61955, -74.02346],
#                 {}
#             ).addTo(map_17ea60095d3be2007fc1ec53bbc0f59e);
#
#
#         var popup_2031387245fe15e2b068bbe80c7f5b2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f7af79f1f8c06286ba32098aa8087e2 = $(`&lt;div id=&quot;html_5f7af79f1f8c06286ba32098aa8087e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;stong&gt;prediction&lt;/stong&gt;&lt;/div&gt;`)[0];
#                 popup_2031387245fe15e2b068bbe80c7f5b2b.setContent(html_5f7af79f1f8c06286ba32098aa8087e2);
#
#
#
#         marker_92f44c9feb804820fa41ceb9f2dbb871.bindPopup(popup_2031387245fe15e2b068bbe80c7f5b2b)
#         ;
#
#
#
#
#             marker_92f44c9feb804820fa41ceb9f2dbb871.bindTooltip(
#                 `&lt;div&gt;
#                      [3]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_575e2e1fa32864d8b50c6d05d6e898b1 = L.marker(
#                 [40.61955, -74.02346],
#                 {}
#             ).addTo(map_17ea60095d3be2007fc1ec53bbc0f59e);
#
#
#         var popup_35e1a9eea65efa7e3af1aee39ba75d27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f9940cc5360c4ce0856749d289451f3 = $(`&lt;div id=&quot;html_8f9940cc5360c4ce0856749d289451f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;stong&gt;prediction&lt;/stong&gt;&lt;/div&gt;`)[0];
#                 popup_35e1a9eea65efa7e3af1aee39ba75d27.setContent(html_8f9940cc5360c4ce0856749d289451f3);
#
#
#
#         marker_575e2e1fa32864d8b50c6d05d6e898b1.bindPopup(popup_35e1a9eea65efa7e3af1aee39ba75d27)
#         ;
#
#
#
#
#             marker_575e2e1fa32864d8b50c6d05d6e898b1.bindTooltip(
#                 `&lt;div&gt;
#                      [3]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6390b507f3e1c02f59e293238c89c9f7 = L.marker(
#                 [40.61955, -74.02346],
#                 {}
#             ).addTo(map_17ea60095d3be2007fc1ec53bbc0f59e);
#
#
#         var popup_5e7ec23066799f59330a7c4e7e2d070f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ad076b3c76ffb2c53678745ca70a98e = $(`&lt;div id=&quot;html_7ad076b3c76ffb2c53678745ca70a98e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;stong&gt;prediction&lt;/stong&gt;&lt;/div&gt;`)[0];
#                 popup_5e7ec23066799f59330a7c4e7e2d070f.setContent(html_7ad076b3c76ffb2c53678745ca70a98e);
#
#
#
#         marker_6390b507f3e1c02f59e293238c89c9f7.bindPopup(popup_5e7ec23066799f59330a7c4e7e2d070f)
#         ;
#
#
#
#
#             marker_6390b507f3e1c02f59e293238c89c9f7.bindTooltip
